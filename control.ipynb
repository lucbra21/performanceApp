# %%
import os 
import polars as pl 
from utils.utils import *

# %%
temp = calculate_metrics_for_94min()
temp
# Out:
# DataFrames salvos em c:\Users\ricar\Desktop\SDC\MIAD\Extensión_Profesional\performanceApp\data\processed\references:
# - Histórico completo: metrics_94min_historical.parquet (119 registros)
# - Últimos 4 jogos: metrics_94min_last_4_games.parquet (38 registros)
# shape: (119, 18)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Player    ┆ Position  ┆ Date      ┆ Total     ┆ … ┆ Decelerat ┆ Dif. ACC/ ┆ Step      ┆ Total    │
# │ ---       ┆ ---       ┆ ---       ┆ Minutes   ┆   ┆ ions_94mi ┆ DEC_94min ┆ Balance   ┆ impacts_ │
# │ str       ┆ str       ┆ str       ┆ en        ┆   ┆ n         ┆ ---       ┆ (%)_94min ┆ 94min    │
# │           ┆           ┆           ┆ Partido   ┆   ┆ ---       ┆ f64       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆ ---       ┆   ┆ f64       ┆           ┆ f64       ┆ f64      │
# ...

# %%
reference = calculate_percentage_difference_vs_reference("30/11/2023")
# Out:
# DataFrames salvos em c:\Users\ricar\Desktop\SDC\MIAD\Extensión_Profesional\performanceApp\data\processed\references:
# - Histórico completo: metrics_94min_historical.parquet (119 registros)
# - Últimos 4 jogos: metrics_94min_last_4_games.parquet (38 registros)
# DataFrames salvos em c:\Users\ricar\Desktop\SDC\MIAD\Extensión_Profesional\performanceApp\data\processed\references:
# - Histórico completo: metrics_94min_historical.parquet (119 registros)
# - Últimos 4 jogos: metrics_94min_last_4_games.parquet (38 registros)
# ...

# %%
reference
# Out:
# shape: (0, 0)
# ┌┐
# ╞╡
# └┘

# %%
data =get_players_data("06/12/2023")
data
# Out:
# shape: (15, 19)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Player    ┆ Position  ┆ Abs       ┆ Abs HSR(m ┆ … ┆ Sprint    ┆ Sprint    ┆ Step      ┆ Total    │
# │ ---       ┆ ---       ┆ HSR(m)    ┆ )/Min     ┆   ┆ Abs (m)   ┆ Rel (m)   ┆ Balance   ┆ impacts  │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ (%)       ┆ ---      │
# │           ┆           ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ ---       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ f64       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Jonathan  ┆ Central   ┆ 360.29077 ┆ 3.006683  ┆ … ┆ 192.03299 ┆ 0.0       ┆ -0.004431 ┆ 25969.0  │
# │ Varane    ┆           ┆ 4         ┆           ┆   ┆ 3         ┆           ┆           ┆          │
# ...

# %%
teste = calculate_player_statistics_94min()

teste
# Out:
# DataFrames salvos em c:\Users\ricar\Desktop\SDC\MIAD\Extensión_Profesional\performanceApp\data\processed\references:
# - Histórico completo: metrics_94min_historical.parquet (119 registros)
# - Últimos 4 jogos: metrics_94min_last_4_games.parquet (38 registros)
# DataFrames salvos em c:\Users\ricar\Desktop\SDC\MIAD\Extensión_Profesional\performanceApp\data\processed\references:
# - Histórico completo: metrics_94min_historical.parquet (119 registros)
# - Últimos 4 jogos: metrics_94min_last_4_games.parquet (38 registros)
# ...

# %%
teste = calculate_player_statistics_94min()

teste
# Out:
# DataFrames salvos em c:\Users\ricar\Desktop\SDC\MIAD\Extensión_Profesional\performanceApp\data\processed\references:
# - Histórico completo: metrics_94min_historical.parquet (119 registros)
# - Últimos 4 jogos: metrics_94min_last_4_games.parquet (38 registros)
# DataFrames salvos em c:\Users\ricar\Desktop\SDC\MIAD\Extensión_Profesional\performanceApp\data\processed\references:
# - Histórico completo: metrics_94min_historical.parquet (119 registros)
# - Últimos 4 jogos: metrics_94min_last_4_games.parquet (38 registros)
# ...

# %%
# import parquet df in data/processed/references
import polars as pl

df = pl.read_parquet('data/processed/references/estadisticas_matchday.parquet')
df
# Out:
# shape: (2_387, 23)
# ┌────────┬──────────┬───────────┬──────────────┬───┬─────────────┬─────────┬─────────┬─────────────┐
# │ Player ┆ Position ┆ Match Day ┆ Estadistica  ┆ … ┆ Step        ┆ Total   ┆ tipo    ┆ Team        │
# │ ---    ┆ ---      ┆ ---       ┆ ---          ┆   ┆ Balance (%) ┆ impacts ┆ ---     ┆ ---         │
# │ str    ┆ str      ┆ str       ┆ str          ┆   ┆ ---         ┆ ---     ┆ str     ┆ str         │
# │        ┆          ┆           ┆              ┆   ┆ f64         ┆ f64     ┆         ┆             │
# ╞════════╪══════════╪═══════════╪══════════════╪═══╪═════════════╪═════════╪═════════╪═════════════╡
# │ Guille ┆ Lateral  ┆ -2 MD     ┆ mean         ┆ … ┆ 0.014793    ┆ 5786.8  ┆ jugador ┆ null        │
# │ Rosas  ┆          ┆           ┆              ┆   ┆             ┆         ┆         ┆             │
# │ Guille ┆ Lateral  ┆ -2 MD     ┆ median       ┆ … ┆ 0.010694    ┆ 5942.5  ┆ jugador ┆ null        │
# ...
