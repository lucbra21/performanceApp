# %%
import os 
import polars as pl 
from utils.utils import *

# %%
duration = calculate_player_statistics_94min()
duration.head(10)
# Out:
# shape: (10, 16)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Player    ┆ estadisti ┆ Distance  ┆ Speed     ┆ … ┆ Decelerat ┆ Dif. ACC/ ┆ Step      ┆ Total    │
# │ ---       ┆ ca        ┆ (m)_94min ┆ Zones (m) ┆   ┆ ions_94mi ┆ DEC_94min ┆ Balance   ┆ impacts_ │
# │ str       ┆ ---       ┆ ---       ┆ [0.0,     ┆   ┆ n         ┆ ---       ┆ (%)_94min ┆ 94min    │
# │           ┆ str       ┆ f64       ┆ 6.0]km/h… ┆   ┆ ---       ┆ f64       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆ ---       ┆   ┆ f64       ┆           ┆ f64       ┆ f64      │
# │           ┆           ┆           ┆ f64       ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Alexandru ┆ max       ┆ 10916.740 ┆ 4197.0952 ┆ … ┆ 2985.4882 ┆ 20.749164 ┆ 0.015587  ┆ 26254.73 │
# ...

# %%
duration = calculate_player_statistics_94min()
jugador = "Christian Rivera"
filtrado = duration.filter(duration["Player"] == jugador)
filtrado.head(10)
# Out:
# shape: (7, 16)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Player    ┆ estadisti ┆ Distance  ┆ Speed     ┆ … ┆ Decelerat ┆ Dif. ACC/ ┆ Step      ┆ Total    │
# │ ---       ┆ ca        ┆ (m)_94min ┆ Zones (m) ┆   ┆ ions_94mi ┆ DEC_94min ┆ Balance   ┆ impacts_ │
# │ str       ┆ ---       ┆ ---       ┆ [0.0,     ┆   ┆ n         ┆ ---       ┆ (%)_94min ┆ 94min    │
# │           ┆ str       ┆ f64       ┆ 6.0]km/h… ┆   ┆ ---       ┆ f64       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆ ---       ┆   ┆ f64       ┆           ┆ f64       ┆ f64      │
# │           ┆           ┆           ┆ f64       ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Christian ┆ max       ┆ 11615.784 ┆ 4318.5483 ┆ … ┆ 2627.4775 ┆ 13.469388 ┆ 0.033525  ┆ 20757.85 │
# ...

# %%
calculate_percentage_difference_vs_reference("30/11/2023")
# Out:
# Error al calcular diferencias porcentuales: Rel HSR(m)
# shape: (0, 0)
# ┌┐
# ╞╡
# └┘

# %%
get_players_data("30/11/2023")
# Out:
# shape: (23, 17)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Player    ┆ Position  ┆ Abs       ┆ Abs HSR(m ┆ … ┆ Sprint    ┆ Sprint    ┆ Step      ┆ Total    │
# │ ---       ┆ ---       ┆ HSR(m)    ┆ )/Min     ┆   ┆ Abs (m)   ┆ Rel (m)   ┆ Balance   ┆ impacts  │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ (%)       ┆ ---      │
# │           ┆           ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ ---       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ f64       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Nacho     ┆ Centrocam ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.008145  ┆ 2668.0   │
# │ Martín    ┆ pista     ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
calculate_player_statistics_94min()
# Out:
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 calculate_player_statistics_94min()
#
# File c:\Users\usuario\performanceApp\utils\utils.py:1496, in calculate_player_statistics_94min()
#    1486 def calculate_player_statistics_94min():
#    1487     """
#    1488     Recibe el DataFrame generado por calculate_metcrics_for_94min y calcula todas las estadísticas
#    1489     agrupadas por jugador para cada métrica. Incluye una columna 'estadistica' que identifica
#    (...)
#    1493         pl.DataFrame: DataFrame con columnas 'Player', 'estadistica' y métricas calculadas por jugador
#    1494     """
# -> 1496     df_94min = calculate_metcrics_for_94min()
#    1498     # Verificar si el DataFrame está vacío
#    1499     if df_94min.is_empty():
#
# File c:\Users\usuario\performanceApp\utils\utils.py:1386, in calculate_metcrics_for_94min()
# ...
