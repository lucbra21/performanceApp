# %%
import pandas as pd
import os
os.getcwd()
# Out:
# 'c:\\Users\\ricar\\Desktop\\SDC\\MIAD\\Extensión_Profesional\\performanceAPP\\PerforamceAPP\\pages'

# %%
df = pd.read_parquet('../data/gps/df_gps.parquet')

# %%
df = df[df['Selection']=='Drills']
df = df[df['Date']=='30/11/2023']
df = df[df['Match Day']!='Rehab']

# %%
df
# Out:
#                     Player   Nick Name              Team         Position  \
# 13790         Nacho Martín       Nacho  Sporting de Gijón  Centrocampista
# 13791     Jonathan  Varane   Jonathan   Sporting de Gijón         Central
# 13792            Enol Coto        Enol  Sporting de Gijón         Lateral
# 13793      Cali Izquierdoz        Cali  Sporting de Gijón         Central
# 13794    José Ángel Valdés  José Ángel  Sporting de Gijón         Lateral
# 13795      Jordan Carrillo      Jordan  Sporting de Gijón  Centrocampista
# 13796   Roque Mesa Quevedo       Roque  Sporting de Gijón  Centrocampista
# 13797       Haissem Hassan     Haissem  Sporting de Gijón       Delantero
# 13798           Juan Otero        Juan  Sporting de Gijón         Extremo
# 13799    Ignacio Jeraldino     Ignacio  Sporting de Gijón       Delantero
# 13800        Diego Sánchez       Diego  Sporting de Gijón         Lateral
# 13801        Gaspar Campos      Gaspar  Sporting de Gijón         Extremo
# ...
